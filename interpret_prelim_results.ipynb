# %%
import pandas as pd
import numpy as np

# %%
res = pd.read_csv('results.csv', index_col='Metadataset')
res.drop('Unnamed: 0', axis=1, inplace=True)
res.max
# Out:
#                               RandomForest  LogisticRegression       SVC  \
# Metadataset
# concept_metadataset.csv           0.351271            0.332763  0.400492
# clustering_metadataset.csv        0.400789            0.359331  0.394930
# all_metadataset.csv               0.406379            0.270295  0.373720
# general_metadataset.csv           0.430717            0.388476  0.415041
# model-based_metadataset.csv       0.411946            0.254585  0.405769
# landmarking_metadataset.csv       0.383639            0.387674  0.383958
# itemset_metadataset.csv           0.368160            0.392556  0.385667
# complexity_metadataset.csv        0.406571            0.250158  0.370444
# info-theory_metadataset.csv       0.391076            0.379545  0.394234
# d2v_pretrained_metadaset.csv      0.376028            0.310414  0.373621
# default_metadataset.csv           0.403799            0.271708  0.394562
# statistical_metadataset.csv       0.383510            0.253621  0.380786
# ...

# %%
# calculate mean of each row
res_df = res.min(axis=1).sort_values(ascending=False).to_frame()
res_df = res_df.reset_index()
res_df.columns = ['Metadataset', 'Max_Accuracy']
res_df
# Out:
#                      Metadataset  Max_Accuracy
# 0       relative_metadataset.csv      0.287653
# 1    landmarking_metadataset.csv      0.281299
# 2    info-theory_metadataset.csv      0.272538
# 3        concept_metadataset.csv      0.270051
# 4        itemset_metadataset.csv      0.250271
# 5    statistical_metadataset.csv      0.228676
# 6     complexity_metadataset.csv      0.223579
# 7     clustering_metadataset.csv      0.204986
# 8        general_metadataset.csv      0.198407
# 9    model-based_metadataset.csv      0.178392
# 10  d2v_pretrained_metadaset.csv      0.164448
# 11           all_metadataset.csv      0.158152
# 12       default_metadataset.csv      0.142604
